# %% [markdown]
# RESNET50

# %% [markdown]
# Parameters

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Parameters': [23528522, 134301514, 3574441, 13441337, 11181642, 2554378, 11181642, 2236682, 128807306, 2554378, 38649859]
}

# Extract data
models = data['Model']
parameters = data['Parameters']

# Create a bar chart
plt.figure(figsize=(10, 6))
bar_positions = np.arange(len(models))
plt.bar(bar_positions, parameters, color='skyblue')

# Add labels and title
plt.xlabel('Model', fontsize=12)
plt.ylabel('Number of Parameters', fontsize=12)
plt.title('Parameter Counts of Models', fontsize=14)
plt.xticks(bar_positions, models, rotation=45, ha='right', fontsize=10)

# Add parameter values above the bars
for i, value in enumerate(parameters):
    plt.text(i, value + (0.05 * value), f'{value:,}', ha='center', fontsize=10)

# Optimize layout and show
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Model Size (MB)': [90.06, 512.33, 90.06, 512.33, 42.73, 9.98, 42.73, 8.77, 491.37, 9.98, 491.37]  # Model sizes in MB
}

# Extract data
models = data['Model']
model_sizes = data['Model Size (MB)']

# Create a bar chart
plt.figure(figsize=(12, 7))
bar_positions = np.arange(len(models))

# Normalize model sizes for color scaling
norm = plt.Normalize(min(model_sizes), max(model_sizes))
colors = cm.viridis(norm(model_sizes))  # Use Viridis colormap


bars = plt.bar(bar_positions, model_sizes, color=colors, alpha=0.8)
# Add labels and title
plt.xlabel('Model', fontsize=13, labelpad=10)
plt.ylabel('Model Size (MB)', fontsize=13, labelpad=10)
plt.title('Comparison of Model Sizes', fontsize=16, pad=15)
plt.xticks(bar_positions, models, rotation=45, ha='right', fontsize=11)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add model size values above the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 3, f'{height:.1f} MB', ha='center', fontsize=11, color='black')

# Optimize layout and show
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'FLOPs (M)': [0.08, 0.43, 0.08, 0.43, 0.04, 0.01, 0.82, 0.31, 0.27, 0.31, 0.27]  # FLOPs in millions
}

# Extract data
models = data['Model']
flops = data['FLOPs (M)']

# Normalize FLOPs for color scaling
norm = plt.Normalize(vmin=min(flops), vmax=max(flops))
colors = cm.plasma(norm(flops))  # Use Plasma colormap

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(models, flops, color=colors, edgecolor='black')

# Add value labels
for bar, value in zip(bars, flops):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005,
            f'{value:.2f}', ha='center', va='bottom', fontsize=10)

# Add color bar for reference
sm = plt.cm.ScalarMappable(cmap='plasma', norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('FLOPs (M)', rotation=270, labelpad=15)

# Customize plot
ax.set_title('FLOPs Comparison Across Models', fontsize=14)
ax.set_ylabel('FLOPs', fontsize=12)
ax.set_xticks(np.arange(len(models)))
ax.set_xticklabels(models, rotation=30, ha='right', fontsize=10)
fig.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Training Time(mins)': [83.2, 38.508, 7.67, 8.09, 58.45, 17.98, 18.93, 23.46, 37.27, 18.65, 9.82]
}

# Extract data
models = data['Model']
flops = data['Training Time(mins)']

# Normalize FLOPs for color scaling
norm = plt.Normalize(vmin=min(flops), vmax=max(flops))
colors = cm.plasma(norm(flops))  # Use Plasma colormap

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(models, flops, color=colors, edgecolor='black')

# Add value labels
for bar, value in zip(bars, flops):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005,
            f'{value:.2f}', ha='center', va='bottom', fontsize=10)

# Add color bar for reference
sm = plt.cm.ScalarMappable(cmap='plasma', norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Training Time', rotation=270, labelpad=15)

# Customize plot
ax.set_title('Training Time Across Models', fontsize=14)
ax.set_ylabel('Training Time', fontsize=12)
ax.set_xticks(np.arange(len(models)))
ax.set_xticklabels(models, rotation=30, ha='right', fontsize=10)
fig.tight_layout()

# Show plot
plt.show()

# import plotly.express as px

# # Sample data
# data = {
#     'Model': ['Pruned', 'Student (KD)', 'KD + Pruned', 'Distilled KD'],
#     'Accuracy': [95, 92, 90, 90],
#     'Parameters': [500, 200, 150, 200]  # Add additional metrics
# }

# # Create a colorful bar plot
# fig = px.bar(
#     data,
#     x='Model',
#     y='Accuracy',
#     color='Total GPU Power Consumption',
#     text='Accuracy',  # Display accuracy on bars
#     title="Model Accuracy vs Total GPU Power Consumption",
#     labels={'Accuracy': 'Accuracy (%)', 'Total GPU Power Consumption': 'Total GPU Power Consumption'},
#     color_continuous_scale="Viridis"  # Fancy color gradient
# )

# # Customize interactivity and layout
# fig.update_traces(texttemplate='%{text}%', textposition='outside')
# fig.update_layout(
#     xaxis_title="Model",
#     yaxis_title="Accuracy (%)",
#     legend_title="Total GPU Power Consumption",
#     font=dict(size=14),
#     template="plotly_dark"
# )

# fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Average Inference Time(seconds)': [0.005944, 0.003640, 0.022866, 0.019839, 0.032430, 0.021753, 0.011133, 0.01099, 0.00349, 0.024419, 0.012557]
}

# Extract data
models = data['Model']
flops = data['Average Inference Time(seconds)']

# Normalize FLOPs for color scaling
norm = plt.Normalize(vmin=min(flops), vmax=max(flops))
colors = cm.plasma(norm(flops))  # Use Plasma colormap

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(models, flops, color=colors, edgecolor='black')

# Add value labels
for bar, value in zip(bars, flops):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005,
            f'{value:.2f}', ha='center', va='bottom', fontsize=10)

# Add color bar for reference
sm = plt.cm.ScalarMappable(cmap='plasma', norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Average Inference Time(seconds)', rotation=270, labelpad=15)

# Customize plot
ax.set_title('Average Inference Time Across Models', fontsize=14)
ax.set_ylabel('Average Inference Time(seconds)', fontsize=12)
ax.set_xticks(np.arange(len(models)))
ax.set_xticklabels(models, rotation=30, ha='right', fontsize=10)
fig.tight_layout()

# Show plot
plt.show()

# import plotly.express as px

# # Sample data
# data = {
#     'Model': ['Pruned', 'Student (KD)', 'KD + Pruned', 'Distilled KD'],
#     'Accuracy': [95, 92, 90, 90],
#     'Parameters': [500, 200, 150, 200]  # Add additional metrics
# }

# # Create a colorful bar plot
# fig = px.bar(
#     data,
#     x='Model',
#     y='Accuracy',
#     color='Total GPU Power Consumption',
#     text='Accuracy',  # Display accuracy on bars
#     title="Model Accuracy vs Total GPU Power Consumption",
#     labels={'Accuracy': 'Accuracy (%)', 'Total GPU Power Consumption': 'Total GPU Power Consumption'},
#     color_continuous_scale="Viridis"  # Fancy color gradient
# )

# # Customize interactivity and layout
# fig.update_traces(texttemplate='%{text}%', textposition='outside')
# fig.update_layout(
#     xaxis_title="Model",
#     yaxis_title="Accuracy (%)",
#     legend_title="Total GPU Power Consumption",
#     font=dict(size=14),
#     template="plotly_dark"
# )

# fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'CO2 Emission (KG)': [0.018974, 0.019935, 0.002061, 0.005567, 0.040562, 0.013418, 0.017445, 0.017186, 0.018779, 0.007747, 0.013890]
}

# Extract data
models = data['Model']
flops = data['CO2 Emission (KG)']

# Normalize FLOPs for color scaling
norm = plt.Normalize(vmin=min(flops), vmax=max(flops))
colors = cm.plasma(norm(flops))  # Use Plasma colormap

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(models, flops, color=colors, edgecolor='black')

# Add value labels
for bar, value in zip(bars, flops):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005,
            f'{value:.2f}', ha='center', va='bottom', fontsize=10)

# Add color bar for reference
sm = plt.cm.ScalarMappable(cmap='plasma', norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('CO2 Emission', rotation=270, labelpad=15)

# Customize plot
ax.set_title('CO2 Emission Across Models', fontsize=14)
ax.set_ylabel('CO2 Emission', fontsize=12)
ax.set_xticks(np.arange(len(models)))
ax.set_xticklabels(models, rotation=30, ha='right', fontsize=10)
fig.tight_layout()

# Show plot
plt.show()

# import plotly.express as px

# # Sample data
# data = {
#     'Model': ['Pruned', 'Student (KD)', 'KD + Pruned', 'Distilled KD'],
#     'Accuracy': [95, 92, 90, 90],
#     'Parameters': [500, 200, 150, 200]  # Add additional metrics
# }

# # Create a colorful bar plot
# fig = px.bar(
#     data,
#     x='Model',
#     y='Accuracy',
#     color='Total GPU Power Consumption',
#     text='Accuracy',  # Display accuracy on bars
#     title="Model Accuracy vs Total GPU Power Consumption",
#     labels={'Accuracy': 'Accuracy (%)', 'Total GPU Power Consumption': 'Total GPU Power Consumption'},
#     color_continuous_scale="Viridis"  # Fancy color gradient
# )

# # Customize interactivity and layout
# fig.update_traces(texttemplate='%{text}%', textposition='outside')
# fig.update_layout(
#     xaxis_title="Model",
#     yaxis_title="Accuracy (%)",
#     legend_title="Total GPU Power Consumption",
#     font=dict(size=14),
#     template="plotly_dark"
# )

# fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Accuracy': [88.53, 91.74, 80.54, 82.53, 87.40, 80.92, 85.56, 82.88, 83.18, 78.43, 80.47]
}

# Extract data
models = data['Model']
parameters = data['Accuracy']

# Create a bar chart
plt.figure(figsize=(10, 6))
bar_positions = np.arange(len(models))
plt.bar(bar_positions, parameters, color='skyblue')

# Add labels and title
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)

plt.title('Accuracy of all Models', fontsize=14)
plt.xticks(bar_positions, models, rotation=45, ha='right', fontsize=10)

# Add parameter values above the bars
for i, value in enumerate(parameters):
    plt.text(i, value + (0.05 * value), f'{value:,}', ha='center', fontsize=10)

# Optimize layout and show
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Accuracy': [88.53, 91.74, 80.54, 82.53, 87.40, 80.92, 85.56, 82.88, 83.18, 78.43, 80.47]
}

# Split the models based on ResNet50 and VGG16 based models
resnet_models = ['Resnet50 Original', 'Pruned ResNet50', 'Dynamic KD (Resnet50 to ResNet18)', 'Dynamic KD (Resnet50 to MobileNetV2)', 'KD ResNet50 to ResNet18', 'KD ResNet50 to MobileNetV2']
vgg_models = ['VGG16 Original', 'Pruned VGG16', 'Dynamic KD (VGG16 to Mobilenet V2)', 'KD VGG16 to VGG11', 'KD VGG16 to MobileNetV2', 'KD+Prune VGG16 to VGG11']

# Extract corresponding accuracies
resnet_accuracies = [88.53, 80.54, 87.40, 80.92, 85.56, 82.88]
vgg_accuracies = [91.74, 82.53, 80.92, 83.18, 78.43, 80.47]

# Plot 1: ResNet50 models
plt.figure(figsize=(10, 6))
bar_positions_resnet = np.arange(len(resnet_models))
plt.bar(bar_positions_resnet, resnet_accuracies, color='lightcoral')

# Add labels and title for ResNet50
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Accuracy of ResNet50-based Models', fontsize=14)
plt.xticks(bar_positions_resnet, resnet_models, rotation=45, ha='right', fontsize=10)

# Add parameter values above the bars for ResNet50
for i, value in enumerate(resnet_accuracies):
    plt.text(i, value + (0.05 * value), f'{value:.2f}', ha='center', fontsize=10)

plt.tight_layout()
plt.show()


# Plot 2: VGG16 models
plt.figure(figsize=(10, 6))
bar_positions_vgg = np.arange(len(vgg_models))
plt.bar(bar_positions_vgg, vgg_accuracies, color='mediumseagreen')

# Add labels and title for VGG16
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Accuracy of VGG16-based Models', fontsize=14)
plt.xticks(bar_positions_vgg, vgg_models, rotation=45, ha='right', fontsize=10)

# Add parameter values above the bars for VGG16
for i, value in enumerate(vgg_accuracies):
    plt.text(i, value + (0.05 * value), f'{value:.2f}', ha='center', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = {
    'Model': [
        'Resnet50 Original',
        'VGG16 Original',
        'Pruned ResNet50',
        'Pruned VGG16',
        'Dynamic KD (Resnet50 to ResNet18)',
        'Dynamic KD (VGG16 to Mobilenet V2)',
        'KD ResNet50 to ResNet18',
        'KD ResNet50 to MobileNetV2',
        'KD VGG16 to VGG11',
        'KD VGG16 to MobileNetV2',
        'KD+Prune VGG16 to VGG11'
    ],
    'Accuracy': [88.53, 91.74, 80.54, 82.53, 87.40, 80.92, 85.56, 82.88, 83.18, 78.43, 80.47]
}

# Extract data
models = data['Model']
accuracy = data['Accuracy']

# Define subsets for each plot
plot_1_models = ['Resnet50 Original', 'VGG16 Original', 'KD ResNet50 to ResNet18', 'KD ResNet50 to MobileNetV2', 'KD VGG16 to VGG11', 'KD VGG16 to MobileNetV2']
plot_1_accuracy = [accuracy[0], accuracy[1], accuracy[6], accuracy[7], accuracy[8], accuracy[9]]

plot_2_models = ['KD ResNet50 to ResNet18', 'Dynamic KD (Resnet50 to ResNet18)', 'KD VGG16 to MobileNetV2', 'Dynamic KD (VGG16 to Mobilenet V2)']
plot_2_accuracy = [accuracy[6], accuracy[4], accuracy[9], accuracy[5]]

plot_3_models = ['Pruned VGG16', 'Pruned ResNet50', 'KD+Prune VGG16 to VGG11', 'KD ResNet50 to ResNet18', 'Dynamic KD (Resnet50 to ResNet18)', 'KD VGG16 to MobileNetV2', 'Dynamic KD (VGG16 to Mobilenet V2)']
plot_3_accuracy = [accuracy[3], accuracy[2], accuracy[10], accuracy[6], accuracy[4], accuracy[9], accuracy[5]]

# Create plots

# Plot 1
plt.figure(figsize=(10, 6))
bar_positions = np.arange(len(plot_1_models))
plt.bar(bar_positions, plot_1_accuracy, color='skyblue')
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Accuracy of Models (Subset 1)', fontsize=14)
plt.xticks(bar_positions, plot_1_models, rotation=45, ha='right', fontsize=10)
for i, value in enumerate(plot_1_accuracy):
    plt.text(i, value + (0.05 * value), f'{value}', ha='center', fontsize=10)
plt.tight_layout()
plt.show()

# %%
# Plot 2
plt.figure(figsize=(8, 6))
bar_positions = np.arange(len(plot_2_models))
plt.bar(bar_positions, plot_2_accuracy, color='lightgreen')
plt.xlabel('Model', fontsize=10)
plt.ylabel('Accuracy', fontsize=10)
plt.title('Accuracy of Models (Subset 2)', fontsize=14)
plt.xticks(bar_positions, plot_2_models, rotation=45, ha='right', fontsize=8)
for i, value in enumerate(plot_2_accuracy):
    plt.text(i, value + (0.05 * value), f'{value}', ha='center', fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Plot 3
plt.figure(figsize=(8, 6))
bar_positions = np.arange(len(plot_3_models))
plt.bar(bar_positions, plot_3_accuracy, color='salmon')
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Accuracy of Models (Subset 3)', fontsize=14)
plt.xticks(bar_positions, plot_3_models, rotation=45, ha='right', fontsize=8)
for i, value in enumerate(plot_3_accuracy):
    plt.text(i, value + (0.05 * value), f'{value}', ha='center', fontsize=8)
plt.tight_layout()
plt.show()
